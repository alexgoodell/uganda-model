# %% [markdown]
# # Variables
#
# Collection of variables need for the model. The first cell (hidden) is used to allow importation of other notebooks.

# %%
import io, os, sys, types
from IPython import get_ipython
from nbformat import read
from IPython.core.interactiveshell import InteractiveShell
sys.path.append(os.path.join(os.path.dirname(''), '..'))

def find_notebook(fullname, path=None):
    """find a notebook, given its fully qualified name and an optional path

    This turns "foo.bar" into "foo/bar.ipynb"
    and tries turning "Foo_Bar" into "Foo Bar" if Foo_Bar
    does not exist.
    """
    name = fullname.rsplit('.', 1)[-1]
    if not path:
        path = ['']
    for d in path:
        nb_path = os.path.join(d, name + ".ipynb")
        if os.path.isfile(nb_path):
            return nb_path
        # let import Notebook_Name find "Notebook Name.ipynb"
        nb_path = nb_path.replace("_", " ")
        if os.path.isfile(nb_path):
            return nb_path

class NotebookLoader(object):
    """Module Loader for Jupyter Notebooks"""
    def __init__(self, path=None):
        self.shell = InteractiveShell.instance()
        self.path = path

    def load_module(self, fullname):
        """import a notebook as a module"""
        path = find_notebook(fullname, self.path)

        print ("importing Jupyter notebook from %s" % path)

        # load the notebook object
        with io.open(path, 'r', encoding='utf-8') as f:
            nb = read(f, 4)


        # create the module and add it to sys.modules
        # if name in sys.modules:
        #    return sys.modules[name]
        mod = types.ModuleType(fullname)
        mod.__file__ = path
        mod.__loader__ = self
        mod.__dict__['get_ipython'] = get_ipython
        sys.modules[fullname] = mod

        # extra work to ensure that magics that would affect the user_ns
        # actually affect the notebook module's ns
        save_user_ns = self.shell.user_ns
        self.shell.user_ns = mod.__dict__

        try:
          for cell in nb.cells:
            if cell.cell_type == 'code':
                # transform the input to executable Python
                code = self.shell.input_transformer_manager.transform_cell(cell.source)
                # run the code in themodule
                exec(code, mod.__dict__)
        finally:
            self.shell.user_ns = save_user_ns
        return mod

class NotebookFinder(object):
    """Module finder that locates Jupyter Notebooks"""
    def __init__(self):
        self.loaders = {}

    def find_module(self, fullname, path=None):
        nb_path = find_notebook(fullname, path)
        if not nb_path:
            return

        key = path
        if path:
            # lists aren't hashable
            key = os.path.sep.join(path)

        if key not in self.loaders:
            self.loaders[key] = NotebookLoader(path)
        return self.loaders[key]

sys.meta_path.append(NotebookFinder())

# %%
# Out:
#                region_name                       district_name           pop  \
# vote_code
# 573        Northern Region                       Abim District  1.294000e+05
# 501        Northern Region                   Adjumani District  2.395000e+05
# 611        Northern Region                      Agago District  2.379000e+05
# 588        Northern Region                   Alebtong District  2.420000e+05
# 564        Northern Region                   Amolatar District  1.616000e+05
# 581        Northern Region                     Amudat District  1.271000e+05
# 565         Eastern Region                     Amuria District  2.964000e+05
# 570        Northern Region                      Amuru District  2.053000e+05
# 502        Northern Region                       Apac District  3.575771e+05
# 793        Northern Region              Apac Municipal Council  4.472290e+04
# 503        Northern Region                       Arua District  7.790000e+05
# 751        Northern Region              Arua Municipal Council  6.750000e+04
# 571         Eastern Region                     Budaka District  2.292000e+05
# 579         Eastern Region                     Bududa District  2.395000e+05
# 504         Eastern Region                     Bugiri District  4.039471e+05
# 795         Eastern Region            Bugiri Municipal Council  3.255289e+04
# 610         Western Region                    Buhweju District  1.358000e+05
# 582         Central Region                     Buikwe District  1.609310e+05
# 578         Eastern Region                    Bukedea District  2.083000e+05
# 600         Central Region               Bukomansimbi District  1.531000e+05
# 567         Eastern Region                      Bukwo District  1.023000e+05
# 589         Eastern Region                  Bulambuli District  2.034000e+05
# 576         Western Region                    Buliisa District  1.297000e+05
# 505         Western Region                 Bundibugyo District  2.418000e+05
# 1006        Western Region                 Bunyangabu District  1.529973e+05
# 506         Western Region                   Bushenyi District  1.998000e+05
# 777         Western Region  Bushenyi- Ishaka Municipal Council  4.220000e+04
# 507         Eastern Region                      Busia District  2.925000e+05
# 776         Eastern Region             Busia Municipal Council  6.090000e+04
# 557         Eastern Region                   Butaleja District  2.718000e+05
# ...                    ...                                 ...           ...
# 603         Eastern Region                      Ngora District  1.535000e+05
# 792         Central Region             Njeru Municipal Council  1.824770e+05
# 595         Western Region                    Ntoroko District  7.030000e+04
# 546         Western Region                   Ntungamo District  4.967000e+05
# 775         Western Region          Ntungamo Municipal Council  2.000000e+04
# 606        Northern Region                      Nwoya District  1.670000e+05
# 615        Northern Region                      Omoro District  1.831311e+05
# 586        Northern Region                      Otuke District  1.192000e+05
# 572        Northern Region                       Oyam District  4.211000e+05
# 547        Northern Region                      Pader District  1.942000e+05
# 1002       Northern Region                    Pakwach District  1.605295e+05
# 548         Eastern Region                    Pallisa District  2.649885e+05
# 549         Central Region                      Rakai District  2.937766e+05
# 616         Western Region                    Rubanda District  2.057227e+05
# 602         Western Region                   Rubirizi District  1.361000e+05
# 1004        Western Region                     Rukiga District  1.053381e+05
# 550         Western Region                  Rukungiri District  2.929000e+05
# 778         Western Region         Rukungiri Municipal Council  3.770000e+04
# 551         Central Region                  Sembabule District  2.728000e+05
# 596         Eastern Region                     Serere District  3.157000e+05
# 609         Western Region                     Sheema District  1.362429e+05
# 796         Western Region            Sheema Municipal Council  8.255709e+04
# 552         Eastern Region                    Sironko District  2.623000e+05
# 553         Eastern Region                     Soroti District  2.727000e+05
# 763         Eastern Region            Soroti Municipal Council  5.450000e+04
# 554         Eastern Region                     Tororo District  5.208000e+05
# 764         Eastern Region            Tororo Municipal Council  4.500000e+04
# 555         Central Region                     Wakiso District  1.165873e+06
# 556        Northern Region                      Yumbe District  5.646000e+05
# 587        Northern Region                      Zombo District  2.599000e+05
#
#            is_hard_to_reach  pop_per_health_fac      rural_pop  public_hosp  \
# vote_code
# 573                       1         6810.526367  108700.244141            1
# 501                       1         7044.117676  195155.629883            1
# 611                       1         5802.438965  207337.515625            1
# 588                       0        11000.000000  234927.570312            0
# 564                       0        12430.769531  138026.873047            0
# 581                       1        12710.000000  113919.257812            0
# 565                       0         8010.811035  288659.751953            0
# 570                       1         5865.714355  194629.738281            0
# 502                       0        10516.973633  349230.191406            1
# 793                       0        44722.898438       0.000000            0
# 503                       0        12365.079102  779000.002930            0
# 751                       0        11250.000000       0.000000            0
# 571                       0         9965.217773  203044.114258            1
# 579                       0        14968.750000  231875.270508            1
# 504                       1         8415.564453  403947.099609            1
# 795                       0         8138.223633       0.000000            0
# 610                       0         9700.000000  132704.256836            0
# 582                       0         6437.241699  133666.710938            1
# 578                       0        13018.750000  201367.019531            0
# 600                       0         6124.000000  143254.990234            0
# 567                       1         6017.646973   93495.491211            1
# 589                       0         8475.000000  184937.702148            0
# 576                       0        10808.333008  121318.737305            1
# 505                       1         9672.000000  200432.825195            1
# 1006                      0         8052.490234  119509.025391            0
# 506                       0         5123.076660  191327.914062            0
# 777                       0        42200.000000       0.000000            0
# 507                       0         6223.404297  292500.002930            1
# 776                       0        30450.000000       0.000000            0
# 557                       0        10872.000000  231610.062500            1
# ...                     ...                 ...            ...          ...
# 603                       0         8527.777344  137277.257812            1
# 792                       0        14036.693359       0.000000            0
# 595                       1        10042.857422   45710.305176            0
# 546                       0        12735.897461  450629.902344            1
