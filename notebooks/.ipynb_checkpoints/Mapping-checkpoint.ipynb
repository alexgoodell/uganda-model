# %%
# Import mapping scripts used to develop maps, see mapper.py

import sys, os
sys.path.append(os.path.join(os.path.dirname(''), '..'))
from lib.dependencies import *
from lib import mapper
import config

# %%
# mapper.cloro('POP2013')

# %%
# Import necessary modules
import geopandas as gpd

# Set filepath 
fp = config.data_path + "/gis/District_Boundaries_2014/District_Boundaries_2014.shp"

# Read file using gpd.read_file()
districts_gdf = gpd.read_file(fp)

# %%
districts_gdf.plot(column='POP2013', cmap='OrRd')

# %%
# import fiona; fiona.supported_drivers

# %%
# districts_gdf.to_file("test")
