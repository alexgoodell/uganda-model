# %% [markdown]
# # Non-physician anesthesthetist (NPA)

# %%
import sys, os
sys.path.append(os.path.join(os.path.dirname(''), '..'))
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd
import numpy as np
from lib import stats_util as su
import config
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import seaborn as sns

# maximizes output
verbose = False

# function for easy printing
def nprint(q):
    print list(q.astype(str))

# %%
# Notes on reading python code
# NaN = not a number, the python equivlent of "null"/"nil"/"NA"
# pandas (pd) is the main data analysis tool and uses dataframes (df), similar to R

# read in data for allied health professionals
df = pd.read_csv(config.data_path + "/ihris/registered-allied-health-professionals-11-3-2018.csv", skiprows=0, header=0)

# %%
# Cleaning
df = su.clean_columns(df)
# show first 5 rows
df.head(2).T
# Out:
#                                                                         0  \
# #                                                                       1
# surname                                                            Okello
# first_name                                                           Alex
# other_names                                                      Morriesh
# cadre                                                    Clinical Officer
# registration_number                                                 14480
# registration_date                                        23 November 2010
# training_qualification  Diploma In Clinical Medicine And Community Health
# training_institution                     Gulu School Of Clinical Officers
# telephone_number                                               0784796713
# email_address                                                         NaN
# person_residence                                  WAKISO, Central, Uganda
# person_nationality                                                 Uganda
#
#                                                                         1
# #                                                                       2
# surname                                                          Rwamwiza
# first_name                                                       Innocent
# other_names                                                           NaN
# cadre                                                    Clinical Officer
# registration_number                                                 14479
# registration_date                                         9 November 2010
# training_qualification  Diploma In Clinical Medicine And Community Health
# training_institution               Fortportal School Of Clinical Officers
# telephone_number                                               0782635445
# email_address                                                         NaN
# person_residence                                  BUIKWE, Central, Uganda
# person_nationality                                                 Uganda

# %%
# Lets look for the anesthesia titles
all_specialties = df.cadre.unique()
all_specialties
# Out:
# array(['Clinical Officer', 'Medical Laboratory Technician',
#        'Health Assistant', 'Medical Laboratory Scientific Officer',
#        'Medical Laboratory Assistant', 'Public Health Dental Officer',
#        'Ophthalmic Clinical Officer', 'Theatre Assistant',
#        'Health Inspector', 'Medical Laboratory Technologist',
#        'Orthopedic Officer', 'Environmental Health Officer',
#        'Physiotherapist', 'Anaesthetic Officer',
#        'Psychiatric Clinical Officer', 'Dispenser',
#        'Orthopedic Technologist', 'Prosthetics-Orthotics',
#        'Anaesthetic Clinical Officer', 'Occupational Therapist',
#        'Medical Radiographer', 'Vector Control Officer',
#        'Ear Nose And Throat Clinical Officer', 'Dental Technologist',
#        'Medical Imaging Technologist', nan,
#        'Medical Laboratory Scientist', 'Pharmacy Assistant',
#        'Medical Sonographer', 'Anaesthetic Assistant'], dtype=object)

# %%
"Best ten results: {}".format(process.extract("anesthesia", all_specialties, limit=10))
# Out:
# "Best ten results: [('Anaesthetic Officer', 72), ('Anaesthetic Clinical Officer', 72), ('Anaesthetic Assistant', 72), ('Health Assistant', 51), ('Theatre Assistant', 51), ('Medical Laboratory Assistant', 45), ('Public Health Dental Officer', 45), ('Environmental Health Officer', 45), ('Physiotherapist', 45), ('Prosthetics-Orthotics', 45)]"

# %%
# Make a df of only the top few
ao = ['Anaesthetic Officer','Anaesthetic Clinical Officer']
aa = ['Anaesthetic Assistant']
either = ao + aa
aodf = df[df.cadre.isin(ao)]
aadf = df[df.cadre.isin(aa)]
adf = df[df.cadre.isin(either)]
adf
# Out:
#            #     surname  first_name        other_names  \
# 68        69     Rukundo      Justus                NaN
# 84        85      Balayo       James                NaN
# 89        90    Ssenteza      Kajubi            Derrick
# 98        99     Kasuubo    Florence                NaN
# 99       100     Kasuubo    Florence                NaN
# 111      112     Nakamya     Magoola          Catherine
# 190      191    Nakaggwa  Bernadette                NaN
# 241      242       Kuule       Yason                NaN
# 354      355       Benda    Margaret                NaN
# 403      404       Taabu     Geofrey                NaN
# 433      434       Kirya      Steven            Kadambi
# 480      481      Mugisa    Jonathan                NaN
# 506      507        Kato      Wilson                NaN
# 651      652  Nyakaisiki      Violet                NaN
# 652      653     Asiimwe       Maria             Gorret
# 671      672     Bakeine     Aheirwe              Alice
# 687      688      Okello       Peter                NaN
# 700      701    Begumisa     Hussein               Khan
# 705      706    Zalwango      Prossy                NaN
# 788      789   Nakitende     Leonite           Katusabe
# 974      975       Achen     Dhorine              Cissy
# 1176    1177   Byamukama      Ernest             Wilson
# 1197    1198      Wobuya       James             Jaycox
# 1207    1208     Basalwa       Sarah                NaN
# 2080    2081      Masika    Felester                NaN
# 2120    2121      Mukasa       Sarah                NaN
# 2166    2167  Kalibakata       Rukia                NaN
# 2338    2339      Baluku      Yasoni         Bitamazire
# 2456    2457     Nadunga    Florence                NaN
# 2457    2458   Nakafeero     Rebecca                NaN
# ...      ...         ...         ...                ...
# 27019  27020      Anyece         Amu            Francis
# 27020  27021        Ashe      Serube  Bafirawala Musoke
# 27021  27022     Asiimwe    Kalekezi              Frank
# 27022  27023         NaN         NaN                NaN
# 27023  27024     Echengu      Alfred                NaN
# 27024  27025     Ejangat      Robert                NaN
# 27025  27026   Ilukunang   Carnelius                  E
# 27026  27027     Kasumba    Namusisi        K   Racheal
# 27027  27028     Katende      Perezi                NaN
# 27028  27029       Kwach      Morris            Marines
# 27029  27030     Madrama      Albert                NaN
# 27030  27031         NaN         NaN                NaN
# 27031  27032   Mugandusi    Florence                NaN
# 27032  27033     Mugenyi      Samuel                NaN
# 27033  27034     Mwandha     Patrick                NaN
# 27034  27035     Naluswa      Prossy                NaN
# 27035  27036   Nyabagabe   Josephine                NaN
# 27036  27037      Opeero        John              David
# 27037  27038      Tollea      Willis                  B
# 27038  27039      Anyait        Mary            Magdale
# 27039  27040       Asege    Florence               Alau
# 27040  27041      Oryono     Charles             Quinox
# 27041  27042         NaN         NaN                NaN
# 27042  27043      Robert       Kidde         Sseruwogge
# 27978  27979      Kiguyi     Geofrey                NaN
# 27984  27985   Khalamova    Svetlana                NaN
# 28115  28116      Alachu       David                NaN
# 28164  28165      Dusabe   Elizabeth                NaN
# 28374  28375         NaN         NaN                NaN
# 28434  28435       Adubi  Ukwairwoth                NaN
#
#                               cadre registration_number registration_date  \
# 68              Anaesthetic Officer               19301   1 November 2012
# 84              Anaesthetic Officer               17434  10 February 2010
# 89              Anaesthetic Officer               15910   24 January 2011
# 98              Anaesthetic Officer              19304.   6 November 2012
# 652                          NaN     KAMWENGE, Western, Uganda
# 671           abakeine@gmail.com       KABALE, Western, Uganda
# 687      okellopeter26@ymail.com      KITGUM, Northern, Uganda
# 700                          NaN      MBARARA, Western, Uganda
# 705                          NaN       LUWERO, Central, Uganda
# 788        leonitenaki@yahoo.com       WAKISO, Central, Uganda
# 974                          NaN  KABERAMAIDO, Eastern, Uganda
# 1176   byamukamaernest@yahoo.com     KABAROLE, Western, Uganda
# 1197                         NaN      MITYANA, Central, Uganda
# 1207                         NaN      KAMPALA, Central, Uganda
# 2080         masikafelesta@gmail       KASESE, Western, Uganda
# 2120         kamaoga@yahoo.co.uk        JINJA, Eastern, Uganda
# 2166                         NaN      KAMPALA, Central, Uganda
# 2338                         NaN       KASESE, Western, Uganda
# 2456                         NaN      KAYUNGA, Central, Uganda
# 2457                         NaN      KAMPALA, Central, Uganda
# ...                          ...                           ...
# 27019                        NaN                           NaN
# 27020                        NaN                           NaN
# 27021                        NaN                           NaN
# 27022                        NaN                           NaN
# 27023                        NaN                           NaN
# 27024                        NaN                           NaN
# 27025                        NaN      KAMPALA, Central, Uganda
# 27026                        NaN                           NaN
# 27027                        NaN                           NaN
# 27028                        NaN       NEBBI, Northern, Uganda
# 27029                        NaN                           NaN
# 27030                        NaN                           NaN
# 27031                        NaN                           NaN
# 27032                        NaN                           NaN
# 27033                        NaN                           NaN
# 27034                        NaN                           NaN
# 27035                        NaN                           NaN
# 27036                        NaN       IGANGA, Eastern, Uganda
# 27037                        NaN        ARUA, Northern, Uganda
# 27038                        NaN                           NaN
# 27039                        NaN      KATAKWI, Eastern, Uganda
# 27040                        NaN       BUDUDA, Eastern, Uganda
# 27041                        NaN                           NaN
# 27042                        NaN        RAKAI, Central, Uganda
# 27978                        NaN    NAMUTUMBA, Eastern, Uganda
# 27984                        NaN      KAMPALA, Central, Uganda
# 28115                        NaN       SOROTI, Eastern, Uganda
# 28164                        NaN       KISORO, Western, Uganda
# 28374                        NaN                           NaN
# 28434                        NaN       NEBBI, Northern, Uganda
#
#        person_nationality
# 68                 Uganda
# 84                 Uganda
# 89                 Uganda
# 98                 Uganda
# 99                 Uganda
# 111                Uganda
# 190                Uganda
# 241                Uganda
# 354                Uganda
# 403                Uganda
# 433                Uganda
# 480                Uganda
# 506                Uganda
# 651                Uganda
# 652                Uganda
# 671                Uganda
# 687                Uganda
# 700                Uganda
# 705                Uganda
# 788                Uganda
# 974                Uganda
# 1176               Uganda
# 1197               Uganda
# 1207               Uganda
# 2080               Uganda
# 2120               Uganda
# 2166               Uganda
# 2338               Uganda
# 2456               Uganda
# 2457               Uganda
# ...                   ...
# 27019              Uganda
# 27020              Uganda
# 27021              Uganda
# 27022                 NaN
# 27023              Uganda
# 27024              Uganda
# 27025              Uganda
# 27026              Uganda
# 27027              Uganda
# 27028              Uganda
# 27029              Uganda
# 27030                 NaN
# 27031              Uganda
# 27032              Uganda
# 27033              Uganda
# 27034              Uganda
# 27035              Uganda
# 27036              Uganda
# 27037              Uganda
# 27038              Uganda
# 27039              Uganda
# 27040              Uganda
# 27041                 NaN
# 27042              Uganda
# 27978              Uganda
# 27984  Russian Federation
# 28115              Uganda
# 28164              Uganda
# 28374                 NaN
# 28434              Uganda
#
# [411 rows x 13 columns]

# %%
# Descriptive
print su.pt(pd.crosstab(
        adf.cadre, columns="count"),
        title = "Cadres of anes allied")
# Out:
#         Cadres of anes allied
#
# |:-----------------------------|----:|
# | Anaesthetic Assistant        |   3 |
# | Anaesthetic Clinical Officer | 238 |
# | Anaesthetic Officer          | 170 |

# %%
# Training qualifications of just ao's
print su.pt(pd.crosstab(
        aodf.training_qualification, columns="count"),
        title = "Training qualification of AOs")
# Out:
#                Training qualification of AOs
#
# |:--------------------------------------------------|----:|
# | Certificate In Environmental Health Science       |   1 |
# | Certificate in Anaesthesia                        |   2 |
# | Certificate of Nursing in Anesthesia              |   1 |
# | Diploma In Anaesthesia                            | 315 |
# | Diploma In Clinical Medicine And Community Health |   1 |
# | Diploma In Public Health Dentistry                |   2 |
# | Post Basic Diploma In Anaesthesia                 |  78 |

# %%
# Training qualifications of just aa's
pd.crosstab(aadf.training_qualification, [aadf.training_institution]).T
# Out:
# training_qualification             Certificate in Anaesthesia
# training_institution
# Mbale School Of Clinical Officers                           3

# %%
# AO training by institution for those with classic training ie...
# ...'Diploma In Anaesthesia', 'Post Basic Diploma In Anaesthesia'
ao_diplomas = ['Diploma In Anaesthesia', 'Post Basic Diploma In Anaesthesia']
q = aodf[aodf.training_qualification.isin(ao_diplomas)]
pd.crosstab(q.training_qualification,[q.training_institution]).T
# Out:
# training_qualification                              Diploma In Anaesthesia  \
# training_institution
# Ataturk University                                                       1
# Fortportal School Of Clinical Officers                                  12
# Gulu Institute Of Health Sciences                                        2
# Jinja Medical Laboratory Training School                                 7
# Kabale Institute Of Health Sciences                                      1
# Kenya Medical Training College Nairobi                                   1
# Kigali Health Institute                                                  1
# Masaka Regional Refferal Hospital                                        2
# Masaka School of Anaesthetic Assistants                                  1
# Mbarara University Of Science And Technology                             4
# Mulago Paramedical Training Schools                                    278
# Soroti School Of Anaesthesia                                             1
# St.Joseph's Hospital Kitovu Medical Laboratory ...                       1
#
# training_qualification                              Post Basic Diploma In Anaesthesia
# training_institution
# Ataturk University                                                                  0
# Fortportal School Of Clinical Officers                                              0
# Gulu Institute Of Health Sciences                                                   0
# Jinja Medical Laboratory Training School                                            0
# Kabale Institute Of Health Sciences                                                 0
# Kenya Medical Training College Nairobi                                              0
# Kigali Health Institute                                                             0
# Masaka Regional Refferal Hospital                                                   0
# Masaka School of Anaesthetic Assistants                                             0
# Mbarara University Of Science And Technology                                        0
# Mulago Paramedical Training Schools                                                78
# Soroti School Of Anaesthesia                                                        0
# St.Joseph's Hospital Kitovu Medical Laboratory ...                                  0

# %%
# AO training by institution for those with non-classic training
q = aodf[~aodf.training_qualification.isin(ao_diplomas)]
pd.crosstab(q.training_qualification,[q.training_institution]).T

# Note below that some of the AOs hold only certificates. For this reason, 
# we'll group AA's and AO's from now on, under non-physician anesthesthetist (NPA)
# this is = adf
# Out:
# training_qualification               Certificate In Environmental Health Science  \
# training_institution
# Makerere University                                                            0
# Mbale School Of Clinical Officers                                              0
# Mbale School Of Hygiene                                                        1
# Mulago Paramedical Training Schools                                            0
#
# training_qualification               Certificate in Anaesthesia  \
# training_institution
# Makerere University                                           0
# Mbale School Of Clinical Officers                             2
# Mbale School Of Hygiene                                       0
# Mulago Paramedical Training Schools                           0
#
# training_qualification               Certificate of Nursing in Anesthesia  \
# training_institution
# Makerere University                                                     1
# Mbale School Of Clinical Officers                                       0
# Mbale School Of Hygiene                                                 0
# Mulago Paramedical Training Schools                                     0
#
# training_qualification               Diploma In Clinical Medicine And Community Health  \
# training_institution
# Makerere University                                                                  0
# Mbale School Of Clinical Officers                                                    1
# Mbale School Of Hygiene                                                              0
# Mulago Paramedical Training Schools                                                  0
#
# training_qualification               Diploma In Public Health Dentistry
# training_institution
# Makerere University                                                   0
# Mbale School Of Clinical Officers                                     0
# Mbale School Of Hygiene                                               0
# Mulago Paramedical Training Schools                                   2

# %%
# Group diplomas by certificate, Diploma, Post-basic, missing, and other
anes_qual = ao_diplomas + ['Certificate in Anaesthesia']
adf.loc[:, "colapsed_qual"] = 0
adf.loc[(~adf.training_qualification.isin(anes_qual))
        & (~adf.training_qualification.isnull()),
        "colapsed_qual"] = 'Other qualification'
adf.loc[adf.training_qualification.isnull(),
        "colapsed_qual"] = 'No qualification listed'
adf.loc[adf.training_qualification.isin(anes_qual),
        "colapsed_qual"] = adf.loc[adf.training_qualification.isin(anes_qual),
        "training_qualification"]
adf.colapsed_qual.unique()
# Out:
# /Users/alexgoodell/.virtualenvs/uganda/lib/python2.7/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/alexgoodell/.virtualenvs/uganda/lib/python2.7/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# array(['Post Basic Diploma In Anaesthesia', 'Diploma In Anaesthesia',
#        'Other qualification', 'Certificate in Anaesthesia',
#        'No qualification listed'], dtype=object)

# %%
# Training years
x = [0, 1990, 2000, 2010, 2020]
y = ['Before 1990', '1991-2000', '2001-2010', '2011-2020']
adf.loc[:,"reg_year"] = adf.registration_date.apply(lambda x: float(x[-4:]))
reg_years = {}
for qual in adf.colapsed_qual.unique():
    reg_years[qual] = pd.cut(adf[adf.colapsed_qual == qual].reg_year, x, labels=y).value_counts()

# mmed_years = pd.cut(ddf[ddf.degree == 'MMed in Anesthesia'].year, x, labels=y).value_counts()
l = pd.DataFrame(reg_years, index=y)
print su.pt(l.T, title="NPA registration by training")
# Out:
#                                  NPA registration by training
#
# |                                   |   Before 1990 |   1991-2000 |   2001-2010 |   2011-2020 |
# |:----------------------------------|--------------:|------------:|------------:|------------:|
# | Certificate in Anaesthesia        |             0 |           0 |           3 |           2 |
# | Diploma In Anaesthesia            |             0 |          55 |         113 |         147 |
# | No qualification listed           |             1 |           0 |           6 |           1 |
# | Other qualification               |             0 |           1 |           3 |           1 |
# | Post Basic Diploma In Anaesthesia |             0 |           7 |          43 |          28 |

# %%
# When did they get they register? (Histogram)

# %matplotlib inline
plt.figure(figsize=(10, 5))
l = adf
l.loc[:,"reg_year_bin"] = pd.cut(l.reg_year, x, labels=y)
sns.countplot(x='reg_year_bin', hue='colapsed_qual', data=l, palette="Greens_d")
_ = plt.xlabel("Registration year")
_ = plt.title("Timeline of NPA registration by training")
_ = plt.legend(bbox_to_anchor=(1, 1))

# %%
# Cumulative registered NPAs assuming no drop-outs (1999-)

adf.loc[:, "dummy"] = 1
p = pd.pivot_table(adf.reset_index(), 
                   values='dummy',
                   index=['reg_year'], 
                   columns=['colapsed_qual'], 
                   aggfunc='sum').fillna(0).cumsum()
# sort
p = p.T.sort_values(2017, ascending=False).T
p
# Out:
# colapsed_qual  Diploma In Anaesthesia  Post Basic Diploma In Anaesthesia  \
# reg_year
# 1943.0                            0.0                                0.0
# 1999.0                           52.0                                4.0
# 2000.0                           55.0                                7.0
# 2001.0                           62.0                                8.0
# 2002.0                           70.0                               11.0
# 2003.0                           77.0                               11.0
# 2004.0                           85.0                               11.0
# 2005.0                          102.0                               18.0
# 2006.0                          115.0                               21.0
# 2007.0                          129.0                               25.0
# 2008.0                          144.0                               28.0
# 2009.0                          156.0                               36.0
# 2010.0                          168.0                               50.0
# 2011.0                          191.0                               54.0
# 2012.0                          226.0                               67.0
# 2013.0                          241.0                               67.0
# 2014.0                          268.0                               70.0
# 2015.0                          284.0                               70.0
# 2016.0                          298.0                               75.0
# 2017.0                          315.0                               78.0
#
# colapsed_qual  No qualification listed  Certificate in Anaesthesia  \
# reg_year
# 1943.0                             1.0                         0.0
# 1999.0                             1.0                         0.0
# 2000.0                             1.0                         0.0
# 2001.0                             1.0                         0.0
# 2002.0                             1.0                         0.0
# 2003.0                             1.0                         0.0
# 2004.0                             1.0                         0.0
# 2005.0                             2.0                         0.0
# 2006.0                             4.0                         0.0
# 2007.0                             6.0                         1.0
# 2008.0                             7.0                         1.0
# 2009.0                             7.0                         1.0
# 2010.0                             7.0                         3.0
# 2011.0                             7.0                         4.0
# 2012.0                             8.0                         5.0
# 2013.0                             8.0                         5.0
# 2014.0                             8.0                         5.0
# 2015.0                             8.0                         5.0
# 2016.0                             8.0                         5.0
# 2017.0                             8.0                         5.0
#
# colapsed_qual  Other qualification
# reg_year
# 1943.0                         0.0
# 1999.0                         1.0
# 2000.0                         1.0
# 2001.0                         1.0
# 2002.0                         2.0
# 2003.0                         2.0
# 2004.0                         2.0
# 2005.0                         2.0
# 2006.0                         2.0
# 2007.0                         2.0
# 2008.0                         2.0
# 2009.0                         4.0
# 2010.0                         4.0
# 2011.0                         4.0
# 2012.0                         4.0
# 2013.0                         4.0
# 2014.0                         4.0
# 2015.0                         4.0
# 2016.0                         5.0
# 2017.0                         5.0

# %%
# Chart since 90's (ignoring the one person who trained in 1943...)

p.loc[1990:].plot.area(figsize=(12, 8))
_ = plt.xlabel("Year")
_ = plt.title("Cumulative registered NPAs assuming no drop-outs by year of registration, (1999-) ")
_ = plt.legend(bbox_to_anchor=(.35, 1))

# %% [markdown]
# # NPA - location

# %%
# Seperate district from rest of
